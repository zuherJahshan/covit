# %%
import matplotlib.pyplot as plt

# %%
# x axis values
x = [1,2,3]
# corresponding y axis values
y = [2,4,1]

# %%
x1 = [1,2,3]
y1 = [2,4,1]
# plotting the line 1 points 
plt.plot(x1, y1, label = "line 1")
  
# line 2 points
x2 = [1,2,3]
y2 = [4,1,3]
# plotting the line 2 points 
plt.plot(x2, y2, label = "line 2")

# giving a title to my graph
plt.title('My first graph!')

# show a legend on the plot
plt.legend()

plt.show()

# %%
'''
You will get as an input a dictionary that will include the following lists:
1. loss
2. top_1_accuracy
3. top_2_accuracy
4. top_5_accuracy
6. val_loss
7. val_top_1_accuracy
8. val_top_2_accuracy
9. val_top_5_accuracy

Options of different graphs
1. top n accuracy graphs (with a flag that specifies whether to include loss)
2. validation-train graphs (with a flag that specifies whether to include loss)
3. loss-val_loss

You also get timings graphs
'''
